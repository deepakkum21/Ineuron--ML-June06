# %% [markdown]
# # online practice

# %%
url = 'https://raw.githubusercontent.com/PramodShenoy/911-Calls/master/911.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(url)
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %%
## find desc operation on categorical and numerical
df.describe()
# Out:
#                 lat           lng           zip        e
# count  99492.000000  99492.000000  86637.000000  99492.0
# mean      40.159526    -75.317464  19237.658298      1.0
# std        0.094446      0.174826    345.344914      0.0
# min       30.333596    -95.595595  17752.000000      1.0
# 25%       40.100423    -75.392104  19038.000000      1.0
# 50%       40.145223    -75.304667  19401.000000      1.0
# 75%       40.229008    -75.212513  19446.000000      1.0
# max       41.167156    -74.995041  77316.000000      1.0

# %%
df[['desc','title','timeStamp','twp','addr']].describe()
# Out:
#                                                      desc  \
# count                                               99492
# unique                                              99455
# top     GREEN ST & E BASIN ST;  NORRISTOWN; Station 30...
# freq                                                    4
#
#                               title            timeStamp           twp  \
# count                         99492                99492         99449
# unique                          110                72577            68
# top     Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:01  LOWER MERION
# freq                          23066                    8          8443
#
#                                      addr
# count                               98973
# unique                              21914
# top     SHANNONDELL DR & SHANNONDELL BLVD
# freq                                  938

# %%
## 
type(df['lat'])
#pd.to_numeric('lat')
df['lat'] = df['lat'].astype('int64')
df
# Out:
#        lat        lng                                               desc  \
# 0       40 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1       40 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2       40 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3       40 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4       40 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
# ...    ...        ...                                                ...
# 99487   40 -75.333515  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...
# 99488   40 -75.289080  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...
# 99489   40 -75.334679  CHESTNUT ST & WALNUT ST;  NORRISTOWN; Station ...
# 99490   40 -75.192555  WELSH RD & WEBSTER LN;  HORSHAM; Station 352; ...
# 99491   40 -75.317952  MORRIS RD & S BROAD ST; UPPER GWYNEDD; 2016-08...
#
#            zip                        title            timeStamp  \
# ...

# %%
df.groupby(['lat']).sum()
# Out:
#               lng           zip      e
# lat
# 30  -9.559559e+01  7.731600e+04      1
# 32  -8.627611e+01  3.610700e+04      1
# 39  -1.111800e+05  2.702675e+07   1477
# 40  -7.382046e+06  1.639535e+09  98012
# 41  -7.687403e+01  1.775200e+04      1

# %%
## smae zip location

df.groupby(['zip']).sum()
# Out:
#            lat           lng    e
# zip
# 17752.0     41    -76.874030    1
# 18036.0     80   -150.923043    2
# 18041.0  16560 -31259.779287  414
# 18054.0  13040 -24603.041115  326
# 18056.0    240   -453.320303    6
# ...        ...           ...  ...
# 19512.0   8800 -16639.521262  220
# 19518.0   2280  -4315.097653   57
# 19525.0  38600 -72948.650072  965
# 36107.0     32    -86.276106    1
# 77316.0     30    -95.595595    1
#
# [104 rows x 3 columns]

# %%
df.dtypes
# Out:
# lat            int64
# lng          float64
# desc          object
# zip          float64
# title         object
# timeStamp     object
# twp           object
# addr          object
# e              int64
# dtype: object

# %%
pd.to_datetime(df['timeStamp'], format='%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     431             try:
# --> 432                 values, tz = conversion.datetime_to_datetime64(arg)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-81fd7d1b6616> in <module>
# ----> 1 pd.to_datetime(df['timeStamp'], format='%Y')
#
# ...

# %%
df.head()
# Out:
#    lat        lng                                               desc      zip  \
# 0   40 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1   40 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2   40 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3   40 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4   40 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
#
#                      title            timeStamp                twp  \
# 0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# ...

# %%
a = df['addr'].str.startswith('A')
a.isnull().sum()
# Out:
# 519

# %%
a.filter()
